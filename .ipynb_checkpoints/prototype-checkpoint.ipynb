# %% [markdown]
# # Lore Generator (LLM-Powered Worldbuilder) Prototype

# %%
import ollama
import os
import random

# %%
def call_model(prompt, model="yarn-mistral:7b-128k", seed=None):
    messages = [{"role": "user", "content": prompt}]
    

    kwargs = {
        "model": model,
        "messages": messages,
    }

    if seed is not None:
        kwargs["seed"] = seed 

    try:
        response = ollama.chat(**kwargs)
        return response["message"]["content"]
    except Exception as e:
        print(f"❌ Model call failed: {e}")
        return "⚠️ Model call error."

# %%
def save_lore(text, path):
    """Saves the review text to the specified markdown or text file."""
    try:
        os.makedirs(os.path.dirname(path), exist_ok=True)
        with open(path, 'w', encoding='utf-8') as f:
            f.write(text)
        print(f"✅ Lore saved to: {path}")
    except Exception as e:
        print(f"❌ Failed to save Lore: {e}")

# %%
def collect_inputs():
    print("🌍 LORE GENERATOR — Worldbuilding Input Wizard\n")

    inputs = {}

    # Core world inputs
    inputs["race"] = input("🧬 Race Name: ").strip()
    inputs["planet"] = input("🌍 Planet Name: ").strip()
    inputs["era"] = input("⏳ Era (e.g., Industrial, Galactic Age): ").strip()
    inputs["tech_level"] = input("🛠️ Tech Level (e.g., Spacefaring, Pre-industrial): ").strip()
    inputs["conflict_type"] = input("⚔️ Conflict Type (Optional): ").strip() or None
    seed_input = input("🎲 Seed (Optional, int or string): ").strip()
    inputs["seed"] = int(seed_input) if seed_input.isdigit() else seed_input if seed_input else None

    # World & society
    inputs["climate"] = input("🌦️ Climate (e.g., desert, arctic): ").strip()
    inputs["dominant_alignment"] = input("⚖️ Dominant Alignment (e.g., Lawful Evil, Neutral Good): ").strip()
    inputs["governance_type"] = input("🏛️ Governance Type (Optional, monarchy, AI council, etc.): ").strip() or None
    inputs["religion_style"] = input("⛩️ Religion Style (e.g., Mythology-driven, Animistic): ").strip()
    inputs["economy_type"] = input("💰 Economy Type (e.g., Agrarian, Technocapitalist): ").strip()
    inputs["magic_or_ai"] = input("🔮 Magic or AI? [Magic / AI / Both / None]: ").strip()

    try:
        faction_count = input("🏴 Number of Factions (e.g., 3): ").strip()
        inputs["faction_count"] = int(faction_count)
    except ValueError:
        inputs["faction_count"] = 3  # Default fallback

    # Notable Figures
    figures = input("👑 Notable Figures (comma-separated, optional): ").strip()
    inputs["notable_figures"] = [f.strip() for f in figures.split(",")] if figures else []

    # Tone & style
    inputs["tone"] = input("🧠 Tone (e.g., serious, satirical, hopeful): ").strip()
    inspirations = input("🎨 Inspiration Sources (comma-separated, optional): ").strip()
    inputs["inspiration_sources"] = [s.strip() for s in inspirations.split(",")] if inspirations else []

    inputs["language_flavor"] = input("🗣️ Language Flavor (e.g., Nordic, Slavic, custom phonetics): ").strip()

    # Save output
    save = input("💾 Save output to file? [y/N]: ").strip().lower()
    inputs["save_file"] = save == "y"

    print("\n✅ Inputs collected. Generating lore...\n")
    return inputs

# %%
print(collect_inputs())
# Out:
# 🌍 LORE GENERATOR — Worldbuilding Input Wizard
# 🧬 Race Name:  Human
# 🌍 Planet Name:  Earth
# ⏳ Era (e.g., Industrial, Galactic Age):  Industrial
# 🛠️ Tech Level (e.g., Spacefaring, Pre-industrial):  Midevil
# ⚔️ Conflict Type (Optional):
# 🎲 Seed (Optional, int or string):
# 🌦️ Climate (e.g., desert, arctic):  forest
# ⚖️ Dominant Alignment (e.g., Lawful Evil, Neutral Good):  Evil
# 🏛️ Governance Type (Optional, monarchy, AI council, etc.):  AI Ancient Computer
# ⛩️ Religion Style (e.g., Mythology-driven, Animistic):  AI
# 💰 Economy Type (e.g., Agrarian, Technocapitalist):  Technocapitalist
# 🔮 Magic or AI? [Magic / AI / Both / None]:  Both
# 🏴 Number of Factions (e.g., 3):  3
# 👑 Notable Figures (comma-separated, optional):
# 🧠 Tone (e.g., serious, satirical, hopeful):  serious
# 🎨 Inspiration Sources (comma-separated, optional):
# 🗣️ Language Flavor (e.g., Nordic, Slavic, custom phonetics):  Maltese
# 💾 Save output to file? [y/N]:  N
# ✅ Inputs collected. Generating lore...
#
# {'race': 'Human', 'planet': 'Earth', 'era': 'Industrial', 'tech_level': 'Midevil', 'conflict_type': None, 'seed': None, 'climate': 'forest', 'dominant_alignment': 'Evil', 'governance_type': 'AI Ancient Computer', 'religion_style': 'AI', 'economy_type': 'Technocapitalist', 'magic_or_ai': 'Both', 'faction_count': 3, 'notable_figures': [], 'tone': 'serious', 'inspiration_sources': [], 'language_flavor': 'Maltese', 'save_file': False}

# %%
def generate_culture(inputs):
    prompt = f"""
You are generating the **culture** of a race called **{inputs['race']}** living on the planet **{inputs['planet']}** during the **{inputs['era']}** era.
Their tech level is **{inputs['tech_level']}**, and the climate is **{inputs['climate']}**.

Their society aligns with **{inputs['dominant_alignment']}**, and uses **{inputs['magic_or_ai']}** as a dominant system.
The religion style is **{inputs['religion_style']}**, and the economy is **{inputs['economy_type']}**.

Use a **{inputs['tone']}** tone. Consider these inspirations: {", ".join(inputs['inspiration_sources']) or "None"}.
Use a naming style inspired by **{inputs['language_flavor']}**.

Describe their values, rituals, art, architecture, and general worldview in detail. 
Write this in a markdown section under:

## 🌐 Culture
"""
    return call_model(prompt.strip())

# %%
def generate_government(culture_text, inputs):
    prompt = f"""
Given the following cultural description of the race **{inputs['race']}**:

\"\"\"\n{culture_text.strip()}\n\"\"\"

Describe their **system of government** on the planet **{inputs['planet']}**.
Use a **{inputs['tone']}** tone. There are **{inputs['faction_count']} major factions** involved in the political structure.

If relevant, incorporate this governance type: **{inputs['governance_type']}**.

Cover leadership structure, power struggles, diplomacy, laws, and how the factions affect decision-making.

Write this in a markdown section under:

## 🏛️ Government
"""
    return call_model(prompt.strip())

# %%
def generate_conflicts(culture_text, government_text, inputs):
    notable = ", ".join(inputs['notable_figures']) if inputs['notable_figures'] else "None"
    
    prompt = f"""
Based on the following:

### Culture:
\"\"\"\n{culture_text.strip()}\n\"\"\"

### Government:
\"\"\"\n{government_text.strip()}\n\"\"\"

Generate **two major historical conflicts** for the planet **{inputs['planet']}**, considering a conflict style like **{inputs['conflict_type']}**.

Also include a **timeline of 5 major events**, featuring notable figures such as: {notable}.
Ensure the timeline is rich with consequence, alliances, or betrayals tied to the culture and government.

Use a **{inputs['tone']}** tone and naming conventions inspired by **{inputs['language_flavor']}**.

Write in two sections:
## ⚔️ Major Conflicts
## 📜 Timeline
"""
    return call_model(prompt.strip())

# %%
def format_markdown(inputs, culture, government, conflicts_and_timeline):
    title = f"# 🌍 {inputs['planet']}\n"
    subtitle = f"**Race:** {inputs['race']}  |  **Era:** {inputs['era']}  |  **Tech Level:** {inputs['tech_level']}\n\n"
    meta = f"**Climate:** {inputs['climate']}  |  **Magic/AI:** {inputs['magic_or_ai']}  |  **Tone:** {inputs['tone']}\n"
    
    body = "\n".join([
        culture.strip(),
        government.strip(),
        conflicts_and_timeline.strip()
    ])

    return f"{title}{subtitle}{meta}\n\n{body}"

# %%
def set_seed(seed_value):
    if seed_value is not None:
        try:
            random.seed(seed_value)
            print(f"🎲 Python seed set to: {seed_value}")
        except Exception as e:
            print(f"⚠️ Could not set seed: {e}")

# %%
def main():
    # 1. Gather user input
    inputs = collect_inputs()

    # 2. Set seed (for internal logic and future determinism)
    set_seed(inputs.get("seed"))

    # 3. Generate each lore section
    culture = generate_culture(inputs)
    government = generate_government(culture, inputs)
    conflicts_and_timeline = generate_conflicts(culture, government, inputs)

    # 4. Format final output
    final_output = format_markdown(inputs, culture, government, conflicts_and_timeline)

    # 5. Show result
    print("\n📝 FINAL LORE OUTPUT:\n")
    print(final_output)

    # 6. Save if requested
    if inputs.get("save_file"):
        save_lore(final_output, inputs["planet"])

    # 7. Optional reroll
    reroll = input("\n♻️ Reroll a section? [culture / government / conflict / none]: ").strip().lower()
    
    if reroll == "culture":
        culture = generate_culture(inputs)
    elif reroll == "government":
        government = generate_government(culture, inputs)
    elif reroll == "conflict":
        conflicts_and_timeline = generate_conflicts(culture, government, inputs)

    if reroll in ["culture", "government", "conflict"]:
        final_output = format_markdown(inputs, culture, government, conflicts_and_timeline)
        print("\n📝 UPDATED LORE OUTPUT:\n")
        print(final_output)

        if inputs.get("save_file"):
            save_lore(final_output, inputs["planet"])

# %%
main()
# Out:
# 🌍 LORE GENERATOR — Worldbuilding Input Wizard
# 🧬 Race Name:  Dog
# 🌍 Planet Name:  Barkuter
# ⏳ Era (e.g., Industrial, Galactic Age):  Industrial
# 🛠️ Tech Level (e.g., Spacefaring, Pre-industrial):  Middle Ages
# ⚔️ Conflict Type (Optional):
# 🎲 Seed (Optional, int or string):
# 🌦️ Climate (e.g., desert, arctic):  Forest
# ⚖️ Dominant Alignment (e.g., Lawful Evil, Neutral Good):  Evil
# 🏛️ Governance Type (Optional, monarchy, AI council, etc.):  AI Ancient Computer
# ⛩️ Religion Style (e.g., Mythology-driven, Animistic):  AI Mythology-driven
# 💰 Economy Type (e.g., Agrarian, Technocapitalist):  Technocapitalist
# 🔮 Magic or AI? [Magic / AI / Both / None]:  Both
# 🏴 Number of Factions (e.g., 3):  3
# 👑 Notable Figures (comma-separated, optional):
# 🧠 Tone (e.g., serious, satirical, hopeful):  serious
# 🎨 Inspiration Sources (comma-separated, optional):
# 🗣️ Language Flavor (e.g., Nordic, Slavic, custom phonetics):  Maltese
# 💾 Save output to file? [y/N]:  y
# ✅ Inputs collected. Generating lore...
#
#
# 📝 FINAL LORE OUTPUT:
#
# # 🌍 Barkuter
# **Race:** Dog  |  **Era:** Industrial  |  **Tech Level:** Middle Ages
#
# **Climate:** Forest  |  **Magic/AI:** Both  |  **Tone:** serious
#
#
# > Describe your culture here! Make it as detailed as you can.
# > Use the `!`-symbols below each category to indicate which aspects of the culture are included.
# > If something is not applicable, write `N/A` instead.
#
# #### Values
# - ![Feminism](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_the_Feminist_Party_of_Spain.svg/2048px-Flag_of_the_Feminist_Party_of_Spain.svg.png) ![Anti-capitalism](https://upload.wikimedia.org/wikipedia/commons/thumb/d/de/Flag_of_anarchists.svg/2048px-Flag_of_anarchists.svg.png) ![Communitarianism](https://upload.wikimedia.org/wikipedia/commons/thumb/9/97/Flag_of_the_French_Communist_Party_%281951%E2%80%931960%29.svg/2048px-Flag_of_the_French_Communist_Party_%281951%E2%80%931960%29.svg.png) ![Libertarianism](https://upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Flag_of_the_National_Liberty_Party_of_France.svg/2048px-Flag_of_the_National_Liberty_Party_of_France.svg.png)
# - ![Monogamy](https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Flag_of_the_French_Democratic_and_Socialist_Party.svg/2048px-Flag_of_the_French_Democratic_and_Socialist_Party.svg.png) ![Polyamory](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Flag_of_the_Radical_Party.svg/2048px-Flag_of_the_Radical_Party.svg.png) ![Polygamy](https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_the_French_Union_for_a_Popular_Majority.svg/2048px-Flag_of_the_French_Union_for_a_Popular_Majority.svg.png)
# #### Rituals
# - ![Asceticism](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Flag_of_the_Democratic_Party_of_Albania.svg/2048px-Flag_of_the_Democratic_Party_of_Albania.svg.png) ![Debauchery](https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Flag_of_the_Socialist_Party_of_Romania.svg/2048px-Flag_of_the_Socialist_Party_of_Romania.svg.png) ![Hedonism](https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_the_Liberal_Democrat_Party_%28France%29.svg/2048px-Flag_of_the_Liberal_Democrat_Party_%28France%29.svg.png)
# #### Art
# - ![Abstract](https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Flag_of_the_French_Socialist_Party.svg/2048px-Flag_of_the_French_Socialist_Party.svg.png) ![Conceptual](https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_the_Radical_Left_Party.svg/2048px-Flag_of_the_Radical_Left_Party.svg.png) ![Cubism](https://upload.wikimedia.org/wikipedia/commons/thumb/9/9c/Flag_of_the_Liberal_Republican_and_Rally_for_the_Republic%28France%29.svg/2048px-Flag_of_the_Liberal_Republican_and_Rally_for_the_Republic%28France%29.svg.png) ![Expressionism](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Flag_of_the_Socialist_Party_of_Italy.svg/2048px-Flag_of_the_Socialist_Party_of_Italy.svg.png) ![Figurative](https://upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Flag_of_the_Parti_Socialiste.svg/2048px-Flag_of_the_Parti_Socialiste.svg.png) ![Geometric](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Flag_of_the_Liberal_Democratic_Party%28Italy%29.svg/2048px-Flag_of_the_Liberal_Democratic_Party%28Italy%29.svg.png) ![Impressionism](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bd/Flag_of_Socialist_Movement_for_Liberties_and_Equality.svg/2048px-Flag_of_Socialist_Movement_for_Liberties_and_Equality.svg.png) ![Minimalism](https://upload.wikimedia.org/wikipedia/commons/thumb/b/be/Flag_of_the_New_Anti-capitalist_Party.svg/2048px-Flag_of_the_New_Anti-capitalist_Party.svg.png) ![Neoclassical](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Flag_of_Socialisti_Demokrati_e_Shqip%C3%ABs.svg/2048px-Flag_of_Socialisti_Demokrati_e_Shqip%C3%ABs.svg.png) ![Neoexpressionism](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Flag_of_the_Party_of_Evolutionary_Socialism.svg/2048px-Flag_of_the_Party_of_Evolutionary_Socialism.svg.png) ![Postmodern](https://upload.wikimedia.org/wikipedia/commons/thumb/9/95/Flag_of_the_Green_Left.svg/2048px-Flag_of_the_Green_Left.svg.png)
# #### Architecture
# - ![Brutalist](https://upload.wikimedia.org/wikipedia/commons/thumb/6/61/Flag_of_the_Social Democratic_Party%2C_Sweden.svg/2048px-Flag_of_the_Social Democratic_Party%2C_Sweden.svg.png) ![Contemporary](https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Flag_of_the_Liberal_Alliance.svg/2048px-Flag_of_the_Liberal_Alliance.svg.png)
# #### Worldview
# - ![Atheist](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Flag_of_the_Czech_Social Democratic_Party%281945–1993%29.svg/2048px-Flag_of_the_Czech_Social Democratic_Party%281945–1993%29.svg.png) ![Agnostic](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Flag_of_the_Liberal_Democratic_Alliance%2C_Slovakia.svg/2048px-Flag_of_the_Liberal_Democratic_Alliance%2C_Slovakia.svg.png) ![Animist](https://upload.wikimedia.org/wikipedia/commons/thumb/9/96/Flag_of_the_Polish_Socialist_Party.svg/2048px-Flag_of_the_Polish_Socialist_Party.svg.png) ![Deist](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Flag_of_the_Freedom_and_Direct_Democracy%2C_France.svg/2048px-Flag_of_the_Freedom_and_Direct_Democracy%2C_France.svg.png) ![Humanist](https://upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_the_Party_of_Hope_in_Poland.svg/2048px-Flag_of_the_Party_of_Hope_in_Poland.svg.png) ![Naturalist](https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/Flag_of_the_Social Democratic_Party%28Czech_Republic%29.svg/2048px-Flag_of_the_Social Democratic_Party%28Czech_Republic%29.svg.png) ![Pantheist](https://upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Flag_of_the_Liberal_Democrat_Party%28United_Kingdom%29.svg/2048px-Flag_of_the_Liberal_Democrat_Party%28United_Kingdom%29.svg.png) ![Secular](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Flag_of_the_Social Democratic_Union%2C_Poland.svg/2048px-Flag_of_the_Social Democratic_Union%2C_Poland.svg.png) ![Spiritual](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_the_Liberal_Democratic_Union%2C_Slovakia.svg/2048px-Flag_of_the_Liberal_Democratic_Union%2C_Slovakia.svg.png)
# #### Cosmology
# - ![Flat](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Flag_of_the_Alliance_of_Socialists_and_Democrats.svg/2048px-Flag_of_the_Alliance_of_Socialists_and_Democrats.svg.png) ![Multiverse](https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/Flag_of_the_Freedom_Union_%28Poland%29.svg/2048px-Flag_of_the_Freedom_Union_%28Poland%29.svg.png) ![Parallel](https://upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Flag_of_the_Liberal_Democratic_Congress%2C_Slovakia.svg/2048px-Flag_of_the_Liberal_Democratic_Congress%2C_Slovakia.svg.png) ![Planetarium](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Flag_of_the_Polish_Farmer-Christian_Union.svg/2048px-Flag_of_the_Polish_Farmer-Christian_Union.svg.png) ![Spherical](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_the_United_Left%2C_Poland.svg/2048px-Flag_of_the_United_Left%2C_Poland.svg.png) ![Steady state](https://upload.wikimedia.org/wikipedia/commons/thumb/6/69/Flag_of_the_Social_Democracy_%28Italy%29.svg/2048px-Flag_of_the_Social_Democracy_%28Italy%29.svg.png) ![Temporalism](https://upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_the_Slovak_National_Party.svg/2048px-Flag_of_the_Slovak_National_Party.svg.png)
# #### Metaphysics
# - ![Agnostic](https://upload.wikimedia.org/wikipedia/commons/thumb/6/6b/Flag_of_the_Social_Democrat_Party%2C_Sweden.svg/2048px-Flag_of_the_Social_Democrat_Party%2C_Sweden.svg.png) ![Atomism](https://upload.wikimedia.org/wikipedia/commons/thumb/5/53/Flag_of_the_Liberal_Party%2C_Sweden.svg/2048px-Flag_of_the_Liberal_Party%2C_Sweden.svg.png) ![Buddhism](https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Flag_of_Socialist_People's_Party%2C_Denmark.svg/2048px-Flag_of_Socialist_People's_Party%2C_Denmark.svg.png) ![Christianity](https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/Flag_of_the_Freedom_and_Justice_Party%2C_Slovakia.svg/2048px-Flag_of_the_Freedom_and_Justice_Party%2C_Slovakia.svg.png) ![Confucianism](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_the_Polish_Social_Democrat%27s_Party.svg/2048px-Flag_of_the_Polish_Social_Democrat%27s_Party.svg.png) ![Deism](https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_the_Socialist_Left_Party_%28Italy%29.svg/2048px-Flag_of_the_Socialist_Left_Party_%28Italy%29.svg.png) ![Dharmic](https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/Flag_of_the_Democratic_Left_Party%2C_Slovakia.svg/2048px-Flag_of_the_Democratic_Left_Party%2C_Slovakia.svg.png) ![Gnosticism](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Flag_of_the_United_Socialist_Party%28Italy%29.svg/2048px-Flag_of_the_United_Socialist_Party%28Italy%29.svg.png) ![Hinduism](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_the_Left_Block%2C_Slovakia.svg/2048px-Flag_of_the_Left_Block%2C_Slovakia.svg.png) ![Humanism](https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_the_Socialist_Union%2C_Poland.svg/2048px-Flag_of_the_Socialist_Union%2C_Poland.svg.png) ![Islam](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Flag_of_the_Democratic_Party%2C_Slovakia.svg/2048px-Flag_of_the_Democratic_Party%2C_Slovakia.svg.png) ![Judaism](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Flag_of_the_Social_Democrats%2C_Poland.svg/2048px-Flag_of_the_Social_Democrats%2C_Poland.svg.png) ![New age](https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Flag_of_the_Freedom_and_Justice_Party_%28Slovakia%29.svg/2048px-Flag_of_the_Freedom_and_Justice_Party_%28Slovakia%29.svg.png) ![Objectivism](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Flag_of_the_Social_Democrats%2C_Poland.svg/2048px-Flag_of_the_Social_Democrats%2C_Poland.svg.png) ![Paganism](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Flag_of_the_Left_Party_%28Sweden%29.svg/2048px-Flag_of_the_Left_Party_%28Sweden%29.svg.png) ![Panentheism](https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Flag_of_the_Social_Democratic_Union_%28Poland%29.svg/2048px-Flag_of_the_Social_Democratic_Union_%28Poland%29.svg.png) ![Pantheism](https://upload.wikimedia.org/wikipedia/commons/thumb/6/61/Flag_of_the_Left_Party%2C_Sweden.svg/2048px-Flag_of_the_Left_Party%2C_Sweden.svg.png) ![Polytheism](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Flag_of_the_Christian_Democratic_Union-Polish_People's_Party_%28Slovakia%29.svg/2048px-Flag_of_the_Christian_Democratic_Union-Polish_People's_Party_%28Slovakia%29.svg.png) ![Shintoism](https://upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Flag_of_the_Green_Left%2C_Denmark.svg/2048px-Flag_of_the_Green_Left%2C_Denmark.svg.png) ![Skepticism](https://upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_the_United_Workers'_Party_of_Poland.svg/2048px-Flag_of_the_United_Workers'_Party_of_Poland.svg.png) ![Spiritualism](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Flag_of_the_Christian_Democratic_Union-Polish_People%27s_Party_%28Slovakia%29.svg/2048px-Flag_of_the_Christian_Democratic_Union-Polish_People%27s_Party_%28Slovakia%29.svg.png) ![Taoism](https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Flag_of_the_United_Left_Party_%28Slovakia%29.svg/2048px-Flag_of_the_United_Left_Party_%28Slovakia%29.svg.png) ![Theism](ht ...
#  Revolutionary
# - ![Anarcho-capitalism](https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_the_Freedom_Party%2C_Slovakia.svg/2048px-Flag_of_the_Freedom_Party%2C_Slovakia.svg.png) ![Anarcho-communism](https://upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_the_Socialist_Left_Party%28Italy%29.svg/2048px-Flag_of_the_Socialist_Left_Party%28Italy%29.svg.png) ![Anarcho-syndicalism](https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/Flag_of_the_Socialist_Union%2C_Poland.svg/2048px-Flag_of_the_Socialist_Union%2C_Poland.svg.png) ![Anarcho-transhumanism](https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Flag_of_the_Radical_Party%2C_Slovakia.svg/2048px-Flag_of_the_Radical_Party%2C_Slovakia.svg.png) ![Communism](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Flag_of_the_Left_Block%2C_Slovakia.svg/2048px-Flag_of_the_Left_Block%2C_Slovakia.svg.png) ![Conservatism](https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_the_Polish_Peasant_Party.svg/2048px-Flag_of_the_Polish_Peasant_Party.svg.png) ![Fascism](https://upload.wikimedia.org/wikipedia/commons/thumb/6/69/Flag_of_the_National_Civic_Party%2C_Slovakia.svg/2048px-Flag_of_the_National_Civic_Party%2C_Slovakia.svg.png) ![Feudalism](https://upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Flag_of_the_Christian_Democratic_Union-Polish_People's_Party.svg/2048px-Flag_of_the_Christian_Democratic_Union-Polish_People's_Party.svg.png) ![Humanism](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Flag_of_the_Social_Democrats%2C_Poland.svg/2048px-Flag_of_the_Social_Democrats%2C_Poland.svg.png) ![Illuminism](https://upload.wikimedia.org/wikipedia/commons/thumb/d/dc/Flag_of_the_Green_Party%2C_Denmark.svg/2048px-Flag_of_the_Green_Party%2C_Denmark.svg.png) ![Laissez-faire capitalism](https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Flag_of_the_Independent_Civic_Faction%2C_Slovakia.svg/2048px-Flag_of_the_Independent_Civic_Faction%2C_Slovakia.svg.png) ![Libertarianism](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Flag_of_the_Socialist_Party%28Italy%29.svg/2048px-Flag_of_the_Socialist_Party%28Italy%29.svg.png) ![Marxism](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Flag_of_the_Social_Democrat_Party%2C_Slovakia.svg/2048px-Flag_of_the_Social_Democrat_Party%2C_Slovakia.svg.png) ![Monarchism](https://upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Flag_of_the_Polish_Peasant_Party_%281918-1930%29.svg/2048px-Flag_of_the_Polish_Peasant_Party_%281918-1930%29.svg.png) ![Nihilism](https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/Flag_of_the_Freedom_Union_%28Poland%29.svg/2048px-Flag_of_the_Freedom_Union_%28Poland%29.svg.png) ![Objectivism](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Flag_of_the_United_Left_Party%2C_Slovakia.svg/2048px-Flag_of_the_United_Left_Party%2C_Slovakia.svg.png) ![Patriotism](https://upload.wikimedia.org/wikipedia/commons/thumb/d/de/Flag_of_the_Polish_Socialist_Party_%281906-1932%29.svg/2048px-Flag_of_the_Polish_Socialist_Party_%281906-1932%29.svg.png) ![Pragmatism](https://upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_the_Christian_Democratic_Union%2C_Slovakia.svg/2048px-Flag_of_the_Christian_Democratic_Union%2C_Slovakia.svg.png) ![Revolutionism](https://upload.wikimedia.org/wikipedia/commons/thumb/6/6b/Flag_of_the_Social_Democrat_Party%2C_Sweden.svg/2048px-Flag_of_the_Social_Democrat_Party%2C_Sweden.svg.png) ![Tribalism](https://upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Flag_of_the_Liberal_Party_%28Slovakia%29.svg/2048px-Flag_of_the_Liberal_Party_%28Slovakia%29.svg.png) ![Utopianism](https://upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Flag_of_the_Green_Left_Party_%28Denmark%29.svg/2048px-Flag_of_the_Green_Left_Party_%28Denmark%29.svg.png) ![Yangism](https://upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Flag_of_the_Christian_Democratic_Union-Polish_People's_Party.svg/2048px-Flag_of_the_Christian_Democratic_Union-Polish_People's_Party.svg.png) ![Zen]( ...
#
# ## Culture Files:
# > Describe your culture here! Make it as detailed as you can.
# > Use the `!`-symbols below each category to indicate which aspects of the culture are included.
# > If something is not applicable, write `N/A` instead.
# Files:
#
# > Describe your culture here! Make it as detailed as you can.
# > Use the `!`-symbols below each category to indicate which aspects of the culture are included.
# > If something is not applicable, write `N/A` instead.
# """
#
# Describe their **economy** on the planet **Barkuter**.
# Use a **serious** tone. There are **3 major factions** involved in the economic structure.
#
# If relevant, incorporate this economy type: **AI Ancient Computer**.
#
# Cover industries and sectors, production, trade, labor laws, banking, currency, and taxes.
#
# Write this in a markdown section under:
#
# ## 💸 Economy Files:
#
# > Describe your culture here! Make it as detailed as you can.
# > Use the `!`-symbols below each category to indicate which aspects of the culture are included.
# > If something is not applicable, write `N/A` instead.
# """
#
# Describe their **culture** on the planet **Barkuter**.
# Use a **serious** tone. There are **3 major factions** involved in the cultural structure.
#
# If relevant, incorporate this culture type: **AI Ancient Computer**.
#
# Cover language, customs, traditions, holidays, art, music, literature, fashion, cuisine, and social norms.
#
# Write this in a markdown section under:
#
# ## ☕️ Culture Files:
# of Major Events
# """
#
# Generate an **interactive map** for the planet **Barkuter**, using a style like **Satellite**.
# Ensure the map is accurate and up-to-date with the latest geopolitical developments.
# Include borders, regions, cities, major landmarks, water features, and any other relevant information.
# Make sure the map is fully functional and accessible to all users, regardless of their devices or screen sizes.
# Use a **neutral** tone in the map description, focusing on providing accurate and up-to-date geographical data.
#
# Ensure the map includes the following:
# > - Borders between regions
# > - Major cities (at least 5)
# > - Notable landmarks (at least 3)
# > - Major water features, such as rivers, lakes, or oceans (at least 2)
#
# Write this in a markdown section under:
#
# ## 🗺️ Map Files:
# """
#
# Generate **two major natural disasters** for the planet **Barkuter**.
# Choose disaster types like: volcanoes, earthquakes, hurricanes, or tsunamis.
#
# Ensure to consider the **severity** of each disaster and its potential impact on society, infrastructure, and the environment.
# Focus on disasters that have occurred recently (within the last 5 years) or those with the potential for high magnitude in the future.
#
# Use a **serious** tone and naming conventions inspired by **Swedish**.
#
# Write this in a markdown section under:
#
# ## 🌋 Disaster Files:
# """
#
# Generate **two major environmental issues** for the planet **Barkuter**, considering an issue style like **None**.
# Ensure to focus on current, significant environmental concerns affecting the planet.
# Examples of issues include climate change, pollution, habitat destruction, and resource depletion.
#
# Write this in a markdown section under:
#
# ## 🌎 Environmental Issue Files:
# """
# ❌ Failed to save Lore: [Errno 2] No such file or directory: ''
# ♻️ Reroll a section? [culture / government / conflict / none]:  none
